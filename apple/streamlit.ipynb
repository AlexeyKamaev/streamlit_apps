# %%
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

import numpy as np
import pandas as pd

import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
def get_closing_prices(symbol, period="1mo"):  # default value of 1 day.
    try:
        ticker = yf.Ticker(symbol)
        data = ticker.history(period)
        return data["Close"]
    except Exception as e:
        print("Failed to get required data.", e)

# %%
ticker = "AAPL"
period = "10y"
prices_data = pd.DataFrame(get_closing_prices(ticker, period)).round()

# %%
ticker2 = "BA"
period2 = "10y"
prices_data2 = pd.DataFrame(get_closing_prices(ticker2, period2)).round()

ticker3 = "DDOG"
period3 = "10y"
prices_data3 = pd.DataFrame(get_closing_prices(ticker3, period3)).round()

ticker4 = "ES=F"
period4 = "10y"
prices_data4 = (pd.DataFrame(get_closing_prices(ticker4, period4))/10).round()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=prices_data.index, y=prices_data['Close'], name = 'Apple'))
fig.add_trace(go.Scatter(x=prices_data2.index, y=prices_data2['Close'], name = 'The Boeing Company'))
fig.add_trace(go.Scatter(x=prices_data3.index, y=prices_data3['Close'], name = 'DataDog'))
fig.add_trace(go.Scatter(x=prices_data4.index, y=prices_data4['Close'], name = 'S&P500'))
fig.update_layout(legend_orientation="h",
                  margin=dict(l=15, r=20, t=30, b=10),
                  legend=dict(x=.5, xanchor="center"),
                  title="American Stocks",
                  hovermode="x",
                  yaxis_title="$ Price",)
fig.update_traces(hoverinfo="all", hovertemplate="Дата: %{x}<br>Цена: %{y}")
fig.show()

# %%
prices_data4 / 10
# Out:
#                            Close
# Date
# 2014-01-16 00:00:00-05:00  183.6
# 2014-01-17 00:00:00-05:00  183.4
# 2014-01-21 00:00:00-05:00  183.8
# 2014-01-22 00:00:00-05:00  183.8
# 2014-01-23 00:00:00-05:00  182.4
# ...                          ...
# 2024-01-10 00:00:00-05:00  482.0
# 2024-01-11 00:00:00-05:00  481.6
# 2024-01-12 00:00:00-05:00  481.6
# 2024-01-15 00:00:00-05:00  481.4
# 2024-01-16 00:00:00-05:00  478.9
#
# [2516 rows x 1 columns]
